# %%
import Pkg;Pkg.add(Pkg.PackageSpec(name="HyperCollate",path="."))
using HyperCollate
include("src/display.jl")
xml = "<text><s><subst><del>Dit kwam van een</del><add>De</add></subst> te streng doorgedreven rationalisatie</s></text>"
tokens = tokenize(xml)
# Out:
# 13-element Array{HyperCollate.XMLToken,1}:
#  HyperCollate.XMLStartElement("text", Dict{String,String}())
#  HyperCollate.XMLStartElement("s", Dict{String,String}())
#  HyperCollate.XMLStartElement("subst", Dict{String,String}())
#  HyperCollate.XMLStartElement("del", Dict{String,String}())
#  HyperCollate.TextToken("Dit kwam van een")
#  HyperCollate.XMLEndElement("del")
#  HyperCollate.XMLStartElement("add", Dict{String,String}())
#  HyperCollate.TextToken("De")
#  HyperCollate.XMLEndElement("add")
#  HyperCollate.XMLEndElement("subst")
#  HyperCollate.TextToken(" te streng doorgedreven rationalisatie")
#  HyperCollate.XMLEndElement("s")
#  HyperCollate.XMLEndElement("text")

# %%
g = to_graph(xml)
# Out:
# {5, 5} undirected Int64 metagraph with Float64 weights defined by :weight (default weight 1.0)

# %%
dot = to_dot(g)
println(dot)
# Out:
# digraph VariantGraph {
#     rankdir=LR
#     labelloc=b
#     color=white
#     edge [arrowsize=0.5]
#     v1[shape=circle;width=0.05;label=""]
# v2[shape=box;label="Dit kwam van een"]
# v3[shape=box;label="De"]
# v4[shape=circle;width=0.05;label=""]
# v5[shape=box;label=" te streng doorgedreven rationalisatie"]
#
# v1 -> v2
# v1 -> v3
# v2 -> v4
# v3 -> v4
# v4 -> v5
#
#
# }

# %%
show_svg(g)
